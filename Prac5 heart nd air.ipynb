# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as rd

# %%
ds_heart = pd.read_csv(r"E:\dataset\heart.csv", sep=",")

# %%
ds = pd.read_csv(r"E:\dataset\data.csv", sep=",", low_memory=False)

# %%
ds.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0      150  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1      151  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2      152  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3      150     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4      151     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date
# 0                         NaN    NaN  01-02-1990
# 1                         NaN    NaN  01-02-1990
# 2                         NaN    NaN  01-02-1990
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
ds.dropna()
# Out:
# Empty DataFrame
# Columns: [stn_code, sampling_date, state, location, agency, type, so2, no2, rspm, spm, location_monitoring_station, pm2_5, date]
# Index: []

# %%
ds.columns
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
ds.columns
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
ds_heart = pd.read_csv(r"E:\dataset\heart.csv")

# %%
ds_heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
ds.columns = ds.columns.str.strip()

# %%
ds_heart.columns = ds_heart.columns.str.strip()

# %%
ds.columns
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
ds1 = ds.loc[111:999, ['sampling_date', 'state', 'so2', 'no2']]

ds2 = ds.iloc[[1,3,5,2,4,22,43,54,67,7,8,9,50,10,11]]

print(ds1.head())

print(ds2.head())
# Out:
#       sampling_date           state   so2   no2
# 111  June - M061992  Andhra Pradesh   4.9  20.8
# 112  June - M061992  Andhra Pradesh   NaN   NaN
# 113  June - M061992  Andhra Pradesh  11.2  22.4
# 114  June - M061992  Andhra Pradesh   4.5  33.9
# 115  June - M061992  Andhra Pradesh   6.2  27.6
#   stn_code       sampling_date           state   location agency  \
# 1      151  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3      150     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 5      152     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 2      152  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 4      151     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 5  Residential, Rural and other Areas  6.4  25.7   NaN  NaN
# ...

# %%
print(ds.columns)
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
ds_integration = pd.concat([ds1,ds2])

# %%
ds_integration
# Out:
#         sampling_date           state   so2   no2 stn_code   location agency  \
# 111    June - M061992  Andhra Pradesh   4.9  20.8      NaN        NaN    NaN
# 112    June - M061992  Andhra Pradesh   NaN   NaN      NaN        NaN    NaN
# 113    June - M061992  Andhra Pradesh  11.2  22.4      NaN        NaN    NaN
# 114    June - M061992  Andhra Pradesh   4.5  33.9      NaN        NaN    NaN
# 115    June - M061992  Andhra Pradesh   6.2  27.6      NaN        NaN    NaN
# ..                ...             ...   ...   ...      ...        ...    ...
# 8     April - M041990  Andhra Pradesh   4.2  23.0      152  Hyderabad    NaN
# 9       May - M051990  Andhra Pradesh   4.0   8.9      151  Hyderabad    NaN
# 50   August - M081991  Andhra Pradesh   8.5  12.5      150  Hyderabad    NaN
# 10      May - M051990  Andhra Pradesh   3.6  18.6      152  Hyderabad    NaN
# 11     June - M061990  Andhra Pradesh   3.9  14.1      150  Hyderabad    NaN
#
# ...

# %%
ds_integration.transpose()
# Out:
#                                         111             112             113  \
# sampling_date                June - M061992  June - M061992  June - M061992
# state                        Andhra Pradesh  Andhra Pradesh  Andhra Pradesh
# so2                                     4.9             NaN            11.2
# no2                                    20.8             NaN            22.4
# stn_code                                NaN             NaN             NaN
# location                                NaN             NaN             NaN
# agency                                  NaN             NaN             NaN
# type                                    NaN             NaN             NaN
# rspm                                    NaN             NaN             NaN
# spm                                     NaN             NaN             NaN
# location_monitoring_station             NaN             NaN             NaN
# ...

# %%
ds = ds.drop(columns="so2")

# %%
ds_merged = pd.concat([ds,ds_heart])
ds_merged
# Out:
#     stn_code       sampling_date           state   location agency  \
# 0        150  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1        151  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2        152  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3        150     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4        151     March - M031990  Andhra Pradesh  Hyderabad    NaN
# ..       ...                 ...             ...        ...    ...
# 298      NaN                 NaN             NaN        NaN    NaN
# 299      NaN                 NaN             NaN        NaN    NaN
# 300      NaN                 NaN             NaN        NaN    NaN
# 301      NaN                 NaN             NaN        NaN    NaN
# 302      NaN                 NaN             NaN        NaN    NaN
#
#                                    type   no2  rspm  spm  \
# 0    Residential, Rural and other Areas  17.4   NaN  NaN
# ...

# %%
ds.columns
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5', 'date'],
#       dtype='object')

# %%
ds['no2'].unique()
# Out:
# array([ 17.4,   7. ,  28.5, ..., 319. , 304. , 200. ], shape=(6865,))

# %%
ds.no2.value_counts()
# Out:
# no2
# 13.0     9447
# 14.0     9386
# 5.0      8738
# 15.0     8693
# 12.0     8490
#          ...
# 234.0       1
# 256.0       1
# 227.0       1
# 218.0       1
# 226.0       1
# Name: count, Length: 6864, dtype: int64
